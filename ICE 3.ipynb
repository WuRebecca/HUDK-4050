# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
os.chdir('C:\\Users\\RebeccaW\\Python')
school = pd.read_csv("ICE1_Data.csv")
graduationCollege = school[['graduation 2010-11', 
                            'college enroll 2010-11']].dropna()

graduation = graduationCollege.loc[:,"graduation 2010-11"].values.reshape(-1,1)
college = graduationCollege.loc[:,"college enroll 2010-11"].values.reshape(-1,1)

graduationCollege.plot.scatter(x = 'graduation 2010-11', 
                              y = 'college enroll 2010-11')
# Out:
# <AxesSubplot:xlabel='graduation 2010-11', ylabel='college enroll 2010-11'>

# %%
model = LinearRegression()
model.fit(graduation, college)
print("The intercept is:", model.intercept_)
print("The slope is:", model.coef_)
# Out:
# The intercept is: [-0.27965123]
# The slope is: [[1.09914898]]

# %%
college_pred = model.predict(graduation)

# %%
plt.scatter(graduation, college)
plt.plot(graduation, college_pred, color = 'red')
plt.show()

# %%
videoData = pd.read_csv("ICE3_data.csv")
videoData
# Out:
#      stid  year video  participation  watch.time  confusion.points  key.points
# 0       1  2018     A              1        16.5                 6           6
# 1       2  2018     A              0         0.0                 0           0
# 2       3  2018     A              1         9.0                 4           6
# 3       4  2018     A              1        20.0                 8           5
# 4       5  2018     A              1        12.0                 8           5
# ..    ...   ...   ...            ...         ...               ...         ...
# 295    56  2019     E              1        12.0                 6           2
# 296    57  2019     E              1        17.5                10           1
# 297    58  2019     E              1         6.0                 4           1
# 298    59  2019     E              0         0.0                 0           0
# 299    60  2019     E              0         0.0                 0           0
#
# [300 rows x 7 columns]

# %%
videoData.describe()
# Out:
#              stid         year  participation  watch.time  confusion.points  \
# count  300.000000   300.000000     300.000000  300.000000        300.000000
# mean    30.500000  2018.500000       0.743333    9.302500          4.426667
# std     17.347038     0.500835       0.437524    8.396475          3.606658
# min      1.000000  2018.000000       0.000000    0.000000          0.000000
# 25%     15.750000  2018.000000       0.000000    0.000000          0.000000
# 50%     30.500000  2018.500000       1.000000    8.375000          5.000000
# 75%     45.250000  2019.000000       1.000000   15.750000          8.000000
# max     60.000000  2019.000000       1.000000   32.500000         13.000000
#
#        key.points
# count  300.000000
# mean     2.326667
# std      1.921526
# min      0.000000
# 25%      0.000000
# 50%      2.000000
# 75%      4.000000
# max      7.000000

# %%
pd.plotting.scatter_matrix(videoData.iloc[:, 3:])
# Out:
# array([[<AxesSubplot:xlabel='participation', ylabel='participation'>,
#         <AxesSubplot:xlabel='watch.time', ylabel='participation'>,
#         <AxesSubplot:xlabel='confusion.points', ylabel='participation'>,
#         <AxesSubplot:xlabel='key.points', ylabel='participation'>],
#        [<AxesSubplot:xlabel='participation', ylabel='watch.time'>,
#         <AxesSubplot:xlabel='watch.time', ylabel='watch.time'>,
#         <AxesSubplot:xlabel='confusion.points', ylabel='watch.time'>,
#         <AxesSubplot:xlabel='key.points', ylabel='watch.time'>],
#        [<AxesSubplot:xlabel='participation', ylabel='confusion.points'>,
#         <AxesSubplot:xlabel='watch.time', ylabel='confusion.points'>,
#         <AxesSubplot:xlabel='confusion.points', ylabel='confusion.points'>,
#         <AxesSubplot:xlabel='key.points', ylabel='confusion.points'>],
#        [<AxesSubplot:xlabel='participation', ylabel='key.points'>,
#         <AxesSubplot:xlabel='watch.time', ylabel='key.points'>,
# ...

# %%
# Rename the plot and graph it
non_normal = pd.plotting.scatter_matrix(videoData.iloc[:, 3:])

# %%
import numpy as np
from scipy import stats
# %matplotlib notebook

# %%
# We take log of the data set in order to normalize it
log = np.log(videoData.iloc[:, 3:])
log
# Out:
#      participation  watch.time  confusion.points  key.points
# 0              0.0    2.803360          1.791759    1.791759
# 1             -inf        -inf              -inf        -inf
# 2              0.0    2.197225          1.386294    1.791759
# 3              0.0    2.995732          2.079442    1.609438
# 4              0.0    2.484907          2.079442    1.609438
# ..             ...         ...               ...         ...
# 295            0.0    2.484907          1.791759    0.693147
# 296            0.0    2.862201          2.302585    0.000000
# 297            0.0    1.791759          1.386294    0.000000
# 298           -inf        -inf              -inf        -inf
# 299           -inf        -inf              -inf        -inf
#
# [300 rows x 4 columns]

# %%
# We do not want the negative infinity values,
# so we need to manually filter them out
indexNames = (log['participation'] != float('-inf')) & (log['watch.time'] != float('-inf')) & (log['confusion.points'] != float('-inf')) & (log['key.points'] != float('-inf'))

# %%
# This is the dataset that we generate
# after we take out the negative infinity.
log[indexNames]
# Out:
#      participation  watch.time  confusion.points  key.points
# 0              0.0    2.803360          1.791759    1.791759
# 2              0.0    2.197225          1.386294    1.791759
# 3              0.0    2.995732          2.079442    1.609438
# 4              0.0    2.484907          2.079442    1.609438
# 5              0.0    2.708050          1.609438    1.386294
# ..             ...         ...               ...         ...
# 293            0.0    2.602690          2.197225    1.098612
# 294            0.0    2.602690          2.197225    0.693147
# 295            0.0    2.484907          1.791759    0.693147
# 296            0.0    2.862201          2.302585    0.000000
# 297            0.0    1.791759          1.386294    0.000000
#
# [201 rows x 4 columns]

# %%
normal = pd.plotting.scatter_matrix(log[indexNames])
# Out:
# <img src="data:image/png;base64,..." width="640">
# D:\ProgramFiles\Anaconda\lib\site-packages\pandas\plotting\_matplotlib\misc.py:80: UserWarning: Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[i])
# D:\ProgramFiles\Anaconda\lib\site-packages\pandas\plotting\_matplotlib\misc.py:90: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   ax.set_ylim(boundaries_list[i])
# D:\ProgramFiles\Anaconda\lib\site-packages\pandas\plotting\_matplotlib\misc.py:89: UserWarning: Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[j])
# D:\ProgramFiles\Anaconda\lib\site-packages\pandas\plotting\_matplotlib\misc.py:104: RuntimeWarning: invalid value encountered in true_divide
#   adj = (locs - lim1[0]) / (lim1[1] - lim1[0])

# %%
Xs = videoData[["participation", "confusion.points",
               "key.points"]].to_numpy()
watchTime = videoData.loc[:, "watch.time"].values.reshape(-1, 1)

# %%
videoModel = LinearRegression()
videoModel.fit(Xs, watchTime)
print("The intercept is:", videoModel.intercept_)
print("The slope is:", videoModel.coef_)
# Out:
# The intercept is: [0.]
# The slope is: [[ 0.55757518  2.08731237 -0.15120358]]

# %%
from statsmodels.api import OLS
videoModelOLS = OLS(watchTime, Xs)
videoModelOLSFit = videoModelOLS.fit()
print(videoModelOLSFit.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.919
# Model:                            OLS   Adj. R-squared (uncentered):              0.918
# Method:                 Least Squares   F-statistic:                              1117.
# Date:                Wed, 13 Oct 2021   Prob (F-statistic):                   2.36e-161
# Time:                        03:23:57   Log-Likelihood:                         -807.73
# No. Observations:                 300   AIC:                                      1621.
# Df Residuals:                     297   BIC:                                      1633.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
# According to the results, x2 has the largest coefficient,
# followed by x1, and x3 has a small negative coefficient.
# It seems like x2 would be a pretty good predictor because
# it shows the strongest correlation with the dependent
# variable y.
